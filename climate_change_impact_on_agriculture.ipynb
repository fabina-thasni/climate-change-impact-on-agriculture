# %% [markdown]
# # Data Description
#
# 1.	Year: The year when the data was recorded.
# 2.	Country: The name of the country where the data was collected.
# 3.	Region: The geographical region where the country is located.
# 4.	Crop_Type: The type of crop being cultivated.
# 5.	Average_Temperature_C: The average temperature in degrees Celsius during the year.
# 6.	Total_Precipitation_mm: The total amount of precipitation (rainfall) in millimeters over the year.
# 7.	CO2_Emissions_MT: The amount of carbon dioxide (CO2) emissions in metric tons.
# 8.	Crop_Yield_MT_per_HA: The crop yield in metric tons per hectare (MT/HA).
# 9.	Extreme_Weather_Events: The number of extreme weather events recorded during the year.
# 10.	Irrigation_Access_%: The percentage of land with access to irrigation systems.
# 11.	Pesticide_Use_KG_per_HA: The amount of pesticide used in kilograms per hectare.
# 12.	Fertilizer_Use_KG_per_HA: The amount of fertilizer used in kilograms per hectare.
# 13.	Soil_Health_Index: A composite score reflecting the overall health and quality of the soil.
# 14.	Adaptation_Strategies: Strategies adopted by the region or country to adapt to changing environmental conditions.
# 15.	Economic_Impact_Million_USD: The economic impact of environmental factors measured in millions of US dollars.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("climate_change_impact_on_agriculture_2024.csv")

# %%
df
# Out:
#       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                     447.06             15.22                 1.737
# 1                    2913.57             29.82                 1.737
# 2                    1301.74             25.75                 1.719
# 3                    1154.36             13.91                 3.890
# 4                    1627.48             11.81                 1.080
# ...                      ...               ...                   ...
# 9995                  685.93             17.64                 3.033
# 9996                 2560.38             10.68                 2.560
# 9997                  357.76             26.01                 1.161
# 9998                 1549.52             17.31                 3.348
# 9999                 1676.25              5.34                 3.710
#
#       Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                          8                14.54                    10.08
# 1                          8                11.05                    33.06
# 2                          5                84.42                    27.41
# 3                          5                94.06                    14.38
# 4                          9                95.75                    44.35
# ...                      ...                  ...                      ...
# 9995                       9                27.56                    41.96
# 9996                       4                77.02                     5.45
# 9997                      10                78.53                    11.94
# 9998                       2                42.65                    44.71
# 9999                       5                46.41                    48.28
#
#       Fertilizer_Use_KG_per_HA  Soil_Health_Index Adaptation_Strategies  \
# 0                        14.78              83.25      Water Management
# 1                        23.25              54.02         Crop Rotation
# 2                        65.53              67.78      Water Management
# 3                        87.58              91.39         No Adaptation
# 4                        88.08              49.61         Crop Rotation
# ...                        ...                ...                   ...
# 9995                     10.95              43.41         No Adaptation
# 9996                     82.32              59.39         No Adaptation
# 9997                     26.00              41.46      Water Management
# 9998                     25.07              75.10         Crop Rotation
# 9999                     98.27              59.38      Water Management
#
#       Economic_Impact_Million_USD
# 0                          808.13
# 1                          616.22
# 2                          796.96
# 3                          790.32
# 4                          401.72
# ...                           ...
# 9995                      1483.06
# 9996                       829.61
# 9997                       155.99
# 9998                      1613.90
# 9999                       453.14
#
# [10000 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Region', 'Crop_Type', 'Average_Temperature_C',
#        'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA',
#        'Extreme_Weather_Events', 'Irrigation_Access_%',
#        'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA',
#        'Soil_Health_Index', 'Adaptation_Strategies',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %% [markdown]
# ### 1.	What is the average yield of each variety of crop?

# %%
avg_yeild_of_crop=df.groupby('Crop_Type')['Crop_Yield_MT_per_HA'].mean().to_frame().reset_index()
avg_yeild_of_crop
# Out:
#     Crop_Type  Crop_Yield_MT_per_HA
# 0      Barley              2.285337
# 1      Coffee              2.224206
# 2        Corn              2.223170
# 3      Cotton              2.171580
# 4      Fruits              2.293362
# 5        Rice              2.249131
# 6    Soybeans              2.226682
# 7   Sugarcane              2.263790
# 8  Vegetables              2.201579
# 9       Wheat              2.266631

# %% [markdown]
# ### 2.	How can crop yield get affected by extreme weather?

# %%
yeild_weather=df['Crop_Yield_MT_per_HA'].corr(df['Extreme_Weather_Events'])
yeild_weather
# Out:
# -0.00509368650652161

# %% [markdown]
# ### 3.	How does the application of fertilizer affect crop yield?

# %%
yeild_fertilizer=df['Crop_Yield_MT_per_HA'].corr(df['Fertilizer_Use_KG_per_HA'])
yeild_fertilizer
# Out:
# 0.006422595479535484

# %% [markdown]
# ### 4.Select all rows where the crop type is "Wheat" and the region is "North West"

# %%
NorthWest_Wheat=df[(df['Crop_Type']=='Wheat')&(df['Region']=='North West')].reset_index(drop=True)
NorthWest_Wheat
# Out:
#     Year  Country      Region Crop_Type  Average_Temperature_C  \
# 0   2006  Nigeria  North West     Wheat                  24.93
# 1   2013  Nigeria  North West     Wheat                  30.60
# 2   2021  Nigeria  North West     Wheat                  -1.79
# 3   2024  Nigeria  North West     Wheat                  15.34
# 4   2001  Nigeria  North West     Wheat                  13.80
# 5   2003  Nigeria  North West     Wheat                  10.47
# 6   2005  Nigeria  North West     Wheat                  -3.02
# 7   2005  Nigeria  North West     Wheat                  27.20
# 8   1995  Nigeria  North West     Wheat                  29.09
# 9   1992  Nigeria  North West     Wheat                  28.22
# 10  1999  Nigeria  North West     Wheat                  -0.40
# 11  2023  Nigeria  North West     Wheat                  13.72
# 12  2004  Nigeria  North West     Wheat                   4.94
# 13  2016  Nigeria  North West     Wheat                  28.10
# 14  2001  Nigeria  North West     Wheat                   1.12
# 15  2010  Nigeria  North West     Wheat                  20.54
# 16  2019  Nigeria  North West     Wheat                  28.52
# 17  1997  Nigeria  North West     Wheat                  23.47
# 18  2014  Nigeria  North West     Wheat                  30.28
# 19  2004  Nigeria  North West     Wheat                  32.54
# 20  2008  Nigeria  North West     Wheat                  29.89
# 21  1995  Nigeria  North West     Wheat                  10.45
# 22  2000  Nigeria  North West     Wheat                  -2.53
# 23  2022  Nigeria  North West     Wheat                  29.75
# 24  1994  Nigeria  North West     Wheat                   8.82
# 25  2003  Nigeria  North West     Wheat                   6.77
# 26  2015  Nigeria  North West     Wheat                  13.76
# 27  2012  Nigeria  North West     Wheat                  17.85
# 28  1994  Nigeria  North West     Wheat                  25.43
# 29  2015  Nigeria  North West     Wheat                   2.05
#
#     Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                   620.17             14.90                 2.640
# 1                  2076.62             11.29                 2.110
# 2                  1182.53             18.45                 2.664
# 3                  2627.50             22.28                 2.385
# 4                  2857.71             12.28                 4.750
# 5                  1470.20             15.86                 1.854
# 6                   989.08              3.39                 0.660
# 7                  2046.86              9.21                 2.440
# 8                   228.15              7.16                 0.747
# 9                   206.26             25.94                 3.177
# 10                 2611.82              5.78                 1.710
# 11                 1438.82             14.23                 2.520
# 12                 1475.19              6.80                 2.590
# 13                 1426.45             22.61                 1.683
# 14                 2697.66             26.74                 1.044
# 15                 2062.55             19.14                 0.873
# 16                  552.27             24.21                 2.880
# 17                  294.55              7.67                 0.747
# 18                 1966.01              8.20                 0.910
# 19                 1162.77             20.07                 3.177
# 20                 1064.10             23.37                 1.044
# 21                 1429.56             12.94                 3.560
# 22                 2581.20             21.41                 0.666
# 23                 2615.64             17.59                 0.936
# 24                  755.82              6.88                 2.390
# 25                  868.37             11.84                 1.510
# 26                 1220.91              7.12                 4.960
# 27                  677.91             12.52                 4.210
# 28                 1548.31              3.39                 2.840
# 29                 1329.14             20.64                 0.945
#
#     Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                        4                86.44                    36.81
# 1                        2                81.17                     6.71
# 2                        2                97.95                    13.06
# 3                        4                48.09                    33.23
# 4                        7                35.34                    27.27
# 5                        8                82.41                    45.88
# 6                        3                15.11                    21.65
# 7                        5                32.66                    42.25
# 8                        9                80.57                    24.09
# 9                        8                17.59                    46.22
# 10                       9                73.08                    44.02
# 11                       3                98.54                     2.63
# 12                       5                26.20                    48.53
# 13                       4                43.20                    29.04
# 14                       9                56.90                    21.69
# 15                       0                45.73                    19.74
# 16                       6                35.36                    11.02
# 17                       4                99.21                    36.21
# 18                       9                82.19                    21.41
# 19                       6                28.51                    31.98
# 20                       5                89.47                     6.45
# 21                       9                54.29                    36.40
# 22                      10                98.39                    32.61
# 23                       7                19.21                    30.37
# 24                       7                41.49                    28.62
# 25                       7                76.19                     3.73
# 26                       7                36.10                    43.00
# 27                       1                51.13                     1.03
# 28                       8                27.21                    33.20
# 29                       7                91.85                    19.79
#
#     Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 0                      39.36              85.30            No Adaptation
# 1                      97.72              57.83  Drought-resistant Crops
# 2                      82.76              91.24            No Adaptation
# 3                      12.24              70.90            Crop Rotation
# 4                      78.86              42.74            Crop Rotation
# 5                      36.12              81.14         Water Management
# 6                      60.86              42.06            Crop Rotation
# 7                      58.12              92.81            Crop Rotation
# 8                      92.87              99.14  Drought-resistant Crops
# 9                      26.39              47.93  Drought-resistant Crops
# 10                     86.64              95.71            No Adaptation
# 11                     29.03              99.90            No Adaptation
# 12                     62.33              98.63            No Adaptation
# 13                     10.45              31.75  Drought-resistant Crops
# 14                     37.05              46.68         Water Management
# 15                     47.83              34.41         Water Management
# 16                     84.11              43.32            No Adaptation
# 17                     84.05              97.66            Crop Rotation
# 18                     17.63              99.02         Water Management
# 19                     87.45              69.50            Crop Rotation
# 20                      9.21              30.94         Water Management
# 21                     39.72              69.89  Drought-resistant Crops
# 22                     48.54              89.84            Crop Rotation
# 23                     42.16              55.84         Water Management
# 24                     96.27              58.63            No Adaptation
# 25                     50.55              97.63         Water Management
# 26                     64.52              76.62         Water Management
# 27                     28.41              83.51         Water Management
# 28                      1.97              65.61         Water Management
# 29                     72.31              66.63            No Adaptation
#
#     Economic_Impact_Million_USD
# 0                        342.62
# 1                        220.21
# 2                        625.08
# 3                        398.37
# 4                        718.85
# 5                        351.48
# 6                        157.88
# 7                        528.19
# 8                        327.20
# 9                        904.39
# 10                       703.99
# 11                       454.10
# 12                       865.06
# 13                       186.33
# 14                       431.73
# 15                       118.44
# 16                      1346.16
# 17                       206.86
# 18                       201.11
# 19                      1211.52
# 20                       494.54
# 21                      1705.60
# 22                       326.26
# 23                       326.57
# 24                       770.07
# 25                       224.14
# 26                      1337.51
# 27                       682.37
# 28                      1262.40
# 29                       204.30

# %% [markdown]
# ### 5.	Which region has experienced the highest average crop yield over the years?

# %%
highest_avg_crop_yeild=df.groupby('Region')['Crop_Yield_MT_per_HA'].mean().sort_values(ascending=False).reset_index()
highest_avg_crop_yeild
# Out:
#                         Region  Crop_Yield_MT_per_HA
# 0                    Southeast              2.412279
# 1                   Tamil Nadu              2.337076
# 2                   Queensland              2.319933
# 3                         West              2.319809
# 4                   South West              2.302296
# 5                    Northwest              2.297377
# 6                   North West              2.294102
# 7                North Central              2.293621
# 8                      Central              2.288494
# 9                       Punjab              2.271368
# 10               Ile-de-France              2.268195
# 11  Provence-Alpes-Cote d’Azur              2.262970
# 12                      Quebec              2.262661
# 13                        East              2.261839
# 14                   Northeast              2.249778
# 15                     Ontario              2.246342
# 16                   Patagonia              2.235052
# 17                  South East              2.227942
# 18            British Columbia              2.221624
# 19             New South Wales              2.220170
# 20           Western Australia              2.214827
# 21                 Maharashtra              2.206846
# 22                       South              2.206420
# 23                       Volga              2.204605
# 24                       North              2.203746
# 25                    Siberian              2.196305
# 26                    Prairies              2.186605
# 27          Nouvelle-Aquitaine              2.181000
# 28                    Victoria              2.180417
# 29                 West Bengal              2.179768
# 30                   Grand Est              2.179476
# 31                     Midwest              2.171324
# 32                      Pampas              2.164554
# 33                Northwestern              2.141357

# %% [markdown]
# ### 6.	How does the average temperature relate to the amount of crops produced?

# %%
temperature_cropyeild=df['Crop_Yield_MT_per_HA'].corr(df['Average_Temperature_C'])
temperature_cropyeild
# Out:
# 0.26378072469850994

# %% [markdown]
# ### 7.	How does CO2 emissions affect crop yield in different regions?

# %%
df.groupby('Region')['CO2_Emissions_MT'].corr(df['Crop_Yield_MT_per_HA']).reset_index()
# Out:
#                         Region  CO2_Emissions_MT
# 0             British Columbia         -0.067986
# 1                      Central         -0.065849
# 2                         East         -0.029002
# 3                    Grand Est         -0.055180
# 4                Ile-de-France         -0.078483
# 5                  Maharashtra         -0.096426
# 6                      Midwest         -0.230737
# 7              New South Wales         -0.109770
# 8                        North         -0.059752
# 9                North Central         -0.169105
# 10                  North West         -0.110377
# 11                   Northeast         -0.088270
# 12                   Northwest         -0.141052
# 13                Northwestern         -0.147745
# 14          Nouvelle-Aquitaine         -0.053544
# 15                     Ontario         -0.132842
# 16                      Pampas         -0.114233
# 17                   Patagonia          0.012844
# 18                    Prairies         -0.069823
# 19  Provence-Alpes-Cote d’Azur          0.021335
# 20                      Punjab         -0.097961
# 21                      Quebec         -0.135774
# 22                  Queensland         -0.063106
# 23                    Siberian         -0.034160
# 24                       South         -0.108175
# 25                  South East         -0.177362
# 26                  South West          0.022919
# 27                   Southeast         -0.179439
# 28                  Tamil Nadu         -0.053210
# 29                    Victoria         -0.099834
# 30                       Volga         -0.044769
# 31                        West         -0.129440
# 32                 West Bengal         -0.092910
# 33           Western Australia         -0.126722

# %% [markdown]
# ### 8.	Which types of crops are more resilient to severe weather conditions?

# %%
df.groupby(['Crop_Type','Extreme_Weather_Events'])['Crop_Yield_MT_per_HA'].max().unstack().idxmax()
# Out:
# Extreme_Weather_Events
# 0        Barley
# 1      Soybeans
# 2         Wheat
# 3      Soybeans
# 4        Barley
# 5      Soybeans
# 6        Coffee
# 7          Rice
# 8          Corn
# 9          Rice
# 10    Sugarcane
# dtype: object

# %% [markdown]
# ### 9.	Which region has the best soil health, and how does it affect pesticide use?

# %%
df.groupby('Region')[['Soil_Health_Index','Pesticide_Use_KG_per_HA']].max().sort_values(by='Soil_Health_Index',ascending=False).head(1)
# Out:
#                             Soil_Health_Index  Pesticide_Use_KG_per_HA
# Region
# Provence-Alpes-Cote d’Azur              100.0                    49.93

# %% [markdown]
# ### 10.	List out 10 rows where the crop yield is below the average yield across all rows.

# %%
avg_yeild=df['Crop_Yield_MT_per_HA'].mean()
avg_yeild
# Out:
# 2.2400169

# %%
below_avg_crop=df.loc[(df['Crop_Yield_MT_per_HA'] < avg_yeild)].head(10).reset_index(drop=True)
below_avg_crop
# Out:
#    Year    Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001      India    West Bengal       Corn                   1.55
# 1  2024      China          North       Corn                   3.23
# 2  2001     France  Ile-de-France      Wheat                  21.11
# 3  1998      India     Tamil Nadu  Sugarcane                   2.19
# 4  2019        USA        Midwest     Coffee                  17.19
# 5  1997  Argentina      Northeast     Fruits                  23.46
# 6  2018    Nigeria     North West     Barley                  21.23
# 7  2017    Nigeria     North West     Coffee                  21.95
# 8  1996  Argentina      Northwest     Coffee                  21.59
# 9  2021     Canada         Quebec     Fruits                  -0.57
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1627.48             11.81                 1.080
# 4                  975.13             10.73                 2.180
# 5                 1816.41             27.70                 1.611
# 6                  475.32             25.74                 0.765
# 7                 2480.33             11.71                 1.370
# 8                  666.95             28.44                 1.584
# 9                 2124.21              7.63                 1.480
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# 1                       8                11.05                    33.06
# 2                       5                84.42                    27.41
# 3                       9                95.75                    44.35
# 4                       5                52.45                    26.06
# 5                       2                20.22                     0.56
# 6                       1                25.74                    44.38
# 7                      10                84.04                    19.86
# 8                      10                41.15                    18.30
# 9                       4                32.79                    42.52
#
#    Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 0                     14.78              83.25         Water Management
# 1                     23.25              54.02            Crop Rotation
# 2                     65.53              67.78         Water Management
# 3                     88.08              49.61            Crop Rotation
# 4                     71.56              97.32         Water Management
# 5                     28.72              79.09          Organic Farming
# 6                     72.92              84.21            No Adaptation
# 7                     21.74              78.53            Crop Rotation
# 8                     85.97              35.89  Drought-resistant Crops
# 9                     85.46              88.57            No Adaptation
#
#    Economic_Impact_Million_USD
# 0                       808.13
# 1                       616.22
# 2                       796.96
# 3                       401.72
# 4                       353.16
# 5                       480.61
# 6                       167.21
# 7                       571.98
# 8                       384.91
# 9                       432.78
